# %% [markdown]
# Custom-CNN (Generalizability Testing)

# %%
# !pip install torchinfo
# Out:
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.11/dist-packages (1.8.0)

# %%
# !pip install grad-cam
# Out:
# Collecting grad-cam
#   Downloading grad-cam-1.5.5.tar.gz (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 77.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from grad-cam) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from grad-cam) (11.2.1)
# Requirement already satisfied: torch>=1.7.1 in /usr/local/lib/python3.11/dist-packages (from grad-cam) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.8.2 in /usr/local/lib/python3.11/dist-packages (from grad-cam) (0.21.0+cu124)
# Collecting ttach (from grad-cam)
#   Downloading ttach-0.0.3-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from grad-cam) (4.67.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from grad-cam) (4.11.0.86)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from grad-cam) (3.7.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from grad-cam) (1.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->grad-cam) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->grad-cam) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->grad-cam) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->grad-cam) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->grad-cam) (2025.5.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.7.1->grad-cam)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.7.1->grad-cam)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.7.1->grad-cam)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.7.1->grad-cam)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.7.1->grad-cam)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.7.1->grad-cam)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.7.1->grad-cam)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.7.1->grad-cam)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.7.1->grad-cam)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->grad-cam) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->grad-cam) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->grad-cam) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.7.1->grad-cam)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->grad-cam) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->grad-cam) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.7.1->grad-cam) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->grad-cam) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->grad-cam) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->grad-cam) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->grad-cam) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->grad-cam) (25.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->grad-cam) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->grad-cam) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->grad-cam) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->grad-cam) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->grad-cam) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->grad-cam) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->grad-cam) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->grad-cam) (2.4.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->grad-cam) (1.15.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->grad-cam) (1.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->grad-cam) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->grad-cam) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.7.1->grad-cam) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->grad-cam) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->grad-cam) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->grad-cam) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->grad-cam) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->grad-cam) (2024.2.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 97.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 77.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 3.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 63.5 MB/s eta 0:00:00
# Downloading ttach-0.0.3-py3-none-any.whl (9.8 kB)
# Building wheels for collected packages: grad-cam
#   Building wheel for grad-cam (pyproject.toml) ... done
#   Created wheel for grad-cam: filename=grad_cam-1.5.5-py3-none-any.whl size=44284 sha256=16104f9ceba9ec5ff52dd5a236e8b596ba62f15b4d8cf6ca463ea7dc75f47f05
#   Stored in directory: /root/.cache/pip/wheels/bc/52/78/893c3b94279ef238f43a9e89608af648de401b96415bebbd1f
# Successfully built grad-cam
# Installing collected packages: ttach, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, grad-cam
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed grad-cam-1.5.5 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ttach-0.0.3

# %% [markdown]
# ### Import Libraries

# %%
import os
import time
import platform
import psutil
import random
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate

from PIL import Image
import PIL

import torch
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchinfo import summary
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

from torchvision import transforms

from torch.cuda.amp import GradScaler, autocast
import torchvision.transforms as T
from sklearn.metrics import confusion_matrix, f1_score
import itertools

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

import cv2
import numpy as np
import matplotlib.pyplot as plt
import torch.nn.functional as F

from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.image import show_cam_on_image, preprocess_image

# %%
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

# %% [markdown]
# ### Configuration

# %%
cpu_info = platform.processor()

ram_info = psutil.virtual_memory()
total_ram_gb = ram_info.total / (1024 ** 3)

try:
    gpu_info = !nvidia-smi --query-gpu=gpu_name --format=csv
    gpu_name = gpu_info[1]
except:
    gpu_name = "No GPU available"

print("CPU:", cpu_info)
print("Total RAM (GB):", round(total_ram_gb, 2))
print("GPU:", gpu_name)
# Out:
# CPU: x86_64
# Total RAM (GB): 31.35
# GPU: Tesla P100-PCIE-16GB

# %% [markdown]
# ### Seed Value

# %%
seed = 1
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

# %% [markdown]
# ### Loading Dataset

# %%
# Path to your new dataset
data_dir = "/kaggle/input/cotton-leaf-disease-dataset/cotton"

file_paths = []
labels = []

# Loop through classes and collect file paths
for class_name in os.listdir(data_dir):
    class_dir = os.path.join(data_dir, class_name)
    for image_name in os.listdir(class_dir):
        file_paths.append(os.path.join(class_dir, image_name))
        labels.append(class_name)

# Create dataframe
df = pd.DataFrame({"file_path": file_paths, "label": labels})
df = df.sample(frac=1).reset_index(drop=True)   # shuffle

# %%
# Map new dataset classes to numbers
label_map = {label: idx for idx, label in enumerate(df["label"].unique())}
num_classes = len(label_map)

# %%
class_counts_train = df['label'].value_counts()

for class_name, count in class_counts_train.items():
    print(f"Class: {class_name}, Count: {count}")

plt.figure(figsize=(14, 5))
ax = class_counts_train.plot(kind='bar')
plt.xlabel('Classes')
plt.ylabel('Amount of data')
plt.xticks(rotation=360)
for i, count in enumerate(class_counts_train):
    ax.text(i, count + 5, str(count), ha='center')
plt.ylim(0, max(class_counts_train) * 1.2)
plt.show()
# Out:
# Class: bacterial_blight, Count: 448
# Class: healthy, Count: 426
# Class: fussarium_wilt, Count: 419
# Class: curl_virus, Count: 418

# %%
random_index = random.randint(1, len(df) - 1)
random_row = df.iloc[random_index]

file_path = random_row['file_path']
label = random_row['label']

image = Image.open(file_path)
plt.imshow(image)
plt.title(f"Label: {label}")
plt.axis('off')
plt.show()

# %% [markdown]
# ### Train-Test-Validation Split (Ratio 70:15:15)

# %%
train_dataframe, temp_dataframe = train_test_split(df, test_size=0.30, 
                                     stratify=df['label'], random_state=42)
valid_dataframe, test_df = train_test_split(temp_dataframe, test_size=0.50, 
                                            stratify=temp_dataframe['label'], random_state=42)

# %%
print("Training Data: ", len(train_dataframe))
print("Validation Data: ", len(valid_dataframe))
print("Test Data: ", len(test_df))
print("-------------------------------------------")
print("Total amounts of data in the dataset: ", len(df))
# Out:
# Training Data:  1197
# Validation Data:  257
# Test Data:  257
# -------------------------------------------
# Total amounts of data in the dataset:  1711

# %%
class_counts_train = train_dataframe['label'].value_counts()
class_counts_valid = valid_dataframe['label'].value_counts()
class_counts_test = test_df['label'].value_counts()

train_table_data = [[class_name, count] for class_name, count in class_counts_train.items()]
valid_table_data = [[class_name, count] for class_name, count in class_counts_valid.items()]
test_table_data = [[class_name, count] for class_name, count in class_counts_test.items()]

print("Train Dataset")
print(tabulate(train_table_data, headers=["Class", "Count"]))
print("\nValidation Dataset")
print(tabulate(valid_table_data, headers=["Class", "Count"]))
print("\nTest Dataset")
print(tabulate(test_table_data, headers=["Class", "Count"]))
# Out:
# Train Dataset
# Class               Count
# ----------------  -------
# bacterial_blight      313
# healthy               298
# curl_virus            293
# fussarium_wilt        293
#
# Validation Dataset
# Class               Count
# ----------------  -------
# bacterial_blight       67
# healthy                64
# curl_virus             63
# fussarium_wilt         63
#
# Test Dataset
# Class               Count
# ----------------  -------
# bacterial_blight       68
# healthy                64
# fussarium_wilt         63
# curl_virus             62

# %% [markdown]
# ### Device Variable

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# ### Checkpoint

# %%
save_path_checkpoints = "/kaggle/working/"
os.makedirs(save_path_checkpoints, exist_ok=True)

# %% [markdown]
# ### Dataset Class, Dataloader and Transform

# %%
class ImageDataset(Dataset):
    def __init__(self, dataframe, transform=None, is_lb=False):
        self.dataframe = dataframe.reset_index(drop=True)
        self.transform = transform
        self.is_lb = is_lb
        self.label_map = label_map

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, index):
        img_path = self.dataframe.iloc[index]['file_path']
        
        try:
            image = Image.open(img_path).convert("RGB")
        except Exception as e:
            print(f"[Warning] Could not load image {img_path}. Error: {e}")
            image = Image.new("RGB", (128, 128), color=(0, 0, 0))
        
        if self.transform:
            image = self.transform(image)

        if self.is_lb:
            label = self.label_map[self.dataframe.iloc[index]['label']]
            return image, label
        else:
            return image, image

# %%
train_batch = 32
val_batch = 8

def data_transfrom():
    # Strong augmentation for training set
    train_transforms = transforms.Compose([
        transforms.RandomResizedCrop(128, scale=(0.8, 1.0)),  # Random crop & resize
        transforms.RandomHorizontalFlip(p=0.5),               # Flip 50% chance
        transforms.RandomRotation(degrees=15),                # Rotate ±15 degrees
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),  # Color change
        transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),  # Small translations
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                             std=[0.229, 0.224, 0.225]),     # Standard ImageNet normalization
        transforms.RandomErasing(p=0.2)                       # Erase random patch
    ])

    # Validation & test transforms (no augmentation)
    val_transforms = transforms.Compose([
        transforms.Resize((128, 128)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                             std=[0.229, 0.224, 0.225])
    ])

    # Create datasets
    train_dataset = ImageDataset(train_dataframe, train_transforms, is_lb=True)
    valid_dataset = ImageDataset(valid_dataframe, val_transforms, is_lb=True)
    test_dataset = ImageDataset(test_df, val_transforms, is_lb=True)

    # Create dataloaders
    dataloader_train_dataset = DataLoader(train_dataset, batch_size=train_batch, shuffle=True, num_workers=2)
    dataloader_valid_dataset = DataLoader(valid_dataset, batch_size=val_batch, shuffle=False, num_workers=2)
    dataloader_test_dataset = DataLoader(test_dataset, batch_size=val_batch, shuffle=False, num_workers=2)

    return dataloader_train_dataset, dataloader_valid_dataset, dataloader_test_dataset

# Load datasets with augmentation
dataloader_train_dataset, dataloader_valid_dataset, dataloader_test_dataset = data_transfrom()

# %% [markdown]
# ### Custom-CNN

# %%
# Custom CNN with Batch Normalization
class CustomCNN(nn.Module):
    def __init__(self, num_classes):
        super(CustomCNN, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, padding=1),     # 128x128x3 → 128x128x16
            nn.BatchNorm2d(16),                              # BN after conv
            nn.ReLU(),
            nn.MaxPool2d(2, 2),                              # → 64x64x16

            nn.Conv2d(16, 32, kernel_size=3, padding=1),     # → 64x64x32
            nn.BatchNorm2d(32),                              # BN after conv
            nn.ReLU(),
            nn.MaxPool2d(2, 2),                              # → 32x32x32

            nn.Conv2d(32, 64, kernel_size=3, padding=1),     # → 32x32x64
            nn.BatchNorm2d(64),                              # BN after conv
            nn.ReLU(),
            nn.AvgPool2d(2, 2),                              # → 16x16x64
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),                                    # → 16*16*64 = 16384
            nn.Linear(64 * 16 * 16, 256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# %% [markdown]
# Model setup block

# %%
# Setup for Custom CNN Model
num_classes = len(label_map)  
learning_rate = 0.001

# Initialize the custom model
model = CustomCNN(num_classes=num_classes).to(device)

# Optimizer and loss function
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)

# Model summary using 128x128 input size
summary(model, input_size=(train_batch, 3, 128, 128))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CustomCNN                                [32, 4]                   --
# ├─Sequential: 1-1                        [32, 64, 16, 16]          --
# │    └─Conv2d: 2-1                       [32, 16, 128, 128]        448
# │    └─BatchNorm2d: 2-2                  [32, 16, 128, 128]        32
# │    └─ReLU: 2-3                         [32, 16, 128, 128]        --
# │    └─MaxPool2d: 2-4                    [32, 16, 64, 64]          --
# │    └─Conv2d: 2-5                       [32, 32, 64, 64]          4,640
# │    └─BatchNorm2d: 2-6                  [32, 32, 64, 64]          64
# │    └─ReLU: 2-7                         [32, 32, 64, 64]          --
# │    └─MaxPool2d: 2-8                    [32, 32, 32, 32]          --
# │    └─Conv2d: 2-9                       [32, 64, 32, 32]          18,496
# │    └─BatchNorm2d: 2-10                 [32, 64, 32, 32]          128
# │    └─ReLU: 2-11                        [32, 64, 32, 32]          --
# │    └─AvgPool2d: 2-12                   [32, 64, 16, 16]          --
# ├─Sequential: 1-2                        [32, 4]                   --
# │    └─Flatten: 2-13                     [32, 16384]               --
# │    └─Linear: 2-14                      [32, 256]                 4,194,560
# │    └─ReLU: 2-15                        [32, 256]                 --
# │    └─Dropout: 2-16                     [32, 256]                 --
# │    └─Linear: 2-17                      [32, 4]                   1,028
# ==========================================================================================
# Total params: 4,219,396
# Trainable params: 4,219,396
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.58
# ==========================================================================================
# Input size (MB): 6.29
# Forward/backward pass size (MB): 234.95
# Params size (MB): 16.88
# Estimated Total Size (MB): 258.12
# ==========================================================================================

# %%
def evaluate_model(model, criterion, dataloader):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            _, predicted = torch.max(outputs, 1)
            running_loss += loss.item() * inputs.size(0)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    loss = running_loss / total
    accuracy = correct / total
    return loss, accuracy

# %%
def train_model(model, criterion, optimizer, dataloader_train_dataset, dataloader_valid_dataset,
                num_epochs=10, early_stop_patience=5, save_path_checkpoints=None):
    
    best_loss = float('inf')
    train_loss_history, train_acc_history = [], []
    val_loss_history, val_acc_history = [], []
    learning_rates = []
    epochs_no_improve = 0

    for epoch in range(num_epochs):
        model.train()
        running_loss, correct, total = 0.0, 0, 0

        for inputs, labels in dataloader_train_dataset:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * inputs.size(0)
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

        epoch_loss = running_loss / total
        epoch_acc = correct / total
        train_loss_history.append(epoch_loss)
        train_acc_history.append(epoch_acc)

        # Evaluate on validation set
        model.eval()
        val_loss, val_acc = evaluate_model(model, criterion, dataloader_valid_dataset)
        val_loss_history.append(val_loss)
        val_acc_history.append(val_acc)
        learning_rates.append(optimizer.param_groups[0]['lr'])

        print(f"Epoch {epoch+1}/{num_epochs} => "
              f"Train Loss: {epoch_loss:.4f}, Train Acc: {epoch_acc:.4f}, "
              f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")

        # Early stopping
        if val_loss < best_loss:
            best_loss = val_loss
            epochs_no_improve = 0
            if save_path_checkpoints:
                torch.save({
                    'epoch': epoch,
                    'model_weight': model.state_dict(),
                    'optimizer_state': optimizer.state_dict(),
                }, os.path.join(save_path_checkpoints, "model.pt"))
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= early_stop_patience:
                print(f"Early stopping at epoch {epoch+1}")
                break

    return train_loss_history, train_acc_history, val_loss_history, val_acc_history, learning_rates

# %% [markdown]
# ### Training

# %%
MODEL_TYPE = "custom"

print(f"\nStarting training for {MODEL_TYPE.upper()} CNN...")
start_time = time.time()

# Train the model
train_loss_history, train_acc_history, val_loss_history, val_acc_history, learning_rates = train_model(
    model, criterion, optimizer, dataloader_train_dataset, dataloader_valid_dataset, 
    num_epochs=500, early_stop_patience=200, save_path_checkpoints=save_path_checkpoints
)

end_time = time.time()
training_time = end_time - start_time
print(f"Training Time: {training_time:.2f} seconds ---> {training_time/60:.2f} minutes")

# Save training history
data = {
    'Epoch': list(range(1, len(train_loss_history) + 1)),
    'Train Loss': train_loss_history,
    'Train Accuracy': train_acc_history,
    'Validation Loss': val_loss_history,
    'Validation Accuracy': val_acc_history,
    'Learning Rate': learning_rates
}

history = pd.DataFrame(data)
history.to_excel(f'/kaggle/working/custom_{MODEL_TYPE}_training_data.xlsx', index=False)
# Out:
# Starting training for CUSTOM CNN...
# Epoch 1/500 => Train Loss: 1.6616, Train Acc: 0.5205, Val Loss: 1.0728, Val Acc: 0.5953
# Epoch 2/500 => Train Loss: 1.0204, Train Acc: 0.6508, Val Loss: 1.0096, Val Acc: 0.6693
# Epoch 3/500 => Train Loss: 0.9871, Train Acc: 0.6683, Val Loss: 0.9239, Val Acc: 0.6732
# Epoch 4/500 => Train Loss: 0.9769, Train Acc: 0.6942, Val Loss: 0.8685, Val Acc: 0.7237
# Epoch 5/500 => Train Loss: 0.9067, Train Acc: 0.7285, Val Loss: 0.8653, Val Acc: 0.7704
# Epoch 6/500 => Train Loss: 0.8940, Train Acc: 0.7310, Val Loss: 0.8164, Val Acc: 0.7626
# Epoch 7/500 => Train Loss: 0.8766, Train Acc: 0.7502, Val Loss: 0.7138, Val Acc: 0.8482
# Epoch 8/500 => Train Loss: 0.8597, Train Acc: 0.7602, Val Loss: 0.7508, Val Acc: 0.8016
# Epoch 9/500 => Train Loss: 0.8770, Train Acc: 0.7661, Val Loss: 0.8643, Val Acc: 0.7704
# Epoch 10/500 => Train Loss: 0.8497, Train Acc: 0.7469, Val Loss: 0.6832, Val Acc: 0.8599
# Epoch 11/500 => Train Loss: 0.8117, Train Acc: 0.7761, Val Loss: 0.7170, Val Acc: 0.8054
# Epoch 12/500 => Train Loss: 0.8507, Train Acc: 0.7410, Val Loss: 0.7203, Val Acc: 0.8288
# Epoch 13/500 => Train Loss: 0.8294, Train Acc: 0.7744, Val Loss: 0.6414, Val Acc: 0.8872
# Epoch 14/500 => Train Loss: 0.7799, Train Acc: 0.7945, Val Loss: 0.6971, Val Acc: 0.8560
# Epoch 15/500 => Train Loss: 0.7853, Train Acc: 0.7987, Val Loss: 0.6740, Val Acc: 0.8444
# Epoch 16/500 => Train Loss: 0.7865, Train Acc: 0.7995, Val Loss: 0.6232, Val Acc: 0.8872
# Epoch 17/500 => Train Loss: 0.7992, Train Acc: 0.7945, Val Loss: 0.6719, Val Acc: 0.8405
# Epoch 18/500 => Train Loss: 0.7746, Train Acc: 0.8003, Val Loss: 0.6322, Val Acc: 0.8521
# Epoch 19/500 => Train Loss: 0.7145, Train Acc: 0.8438, Val Loss: 0.6520, Val Acc: 0.8716
# Epoch 20/500 => Train Loss: 0.7605, Train Acc: 0.8271, Val Loss: 0.6419, Val Acc: 0.8716
# Epoch 21/500 => Train Loss: 0.7514, Train Acc: 0.8187, Val Loss: 0.7389, Val Acc: 0.8171
# Epoch 22/500 => Train Loss: 0.7400, Train Acc: 0.8329, Val Loss: 0.6153, Val Acc: 0.8794
# Epoch 23/500 => Train Loss: 0.7210, Train Acc: 0.8363, Val Loss: 0.6188, Val Acc: 0.9027
# Epoch 24/500 => Train Loss: 0.7020, Train Acc: 0.8446, Val Loss: 0.6676, Val Acc: 0.8716
# Epoch 25/500 => Train Loss: 0.7043, Train Acc: 0.8404, Val Loss: 0.5947, Val Acc: 0.8833
# Epoch 26/500 => Train Loss: 0.7107, Train Acc: 0.8546, Val Loss: 0.7162, Val Acc: 0.8249
# Epoch 27/500 => Train Loss: 0.7309, Train Acc: 0.8463, Val Loss: 0.5899, Val Acc: 0.8755
# Epoch 28/500 => Train Loss: 0.6948, Train Acc: 0.8480, Val Loss: 0.6054, Val Acc: 0.8677
# Epoch 29/500 => Train Loss: 0.6847, Train Acc: 0.8404, Val Loss: 0.5641, Val Acc: 0.8794
# Epoch 30/500 => Train Loss: 0.6791, Train Acc: 0.8580, Val Loss: 0.5538, Val Acc: 0.9144
# Epoch 31/500 => Train Loss: 0.6644, Train Acc: 0.8647, Val Loss: 0.6902, Val Acc: 0.8288
# Epoch 32/500 => Train Loss: 0.6719, Train Acc: 0.8605, Val Loss: 0.5573, Val Acc: 0.9105
# Epoch 33/500 => Train Loss: 0.6645, Train Acc: 0.8638, Val Loss: 0.5797, Val Acc: 0.8911
# Epoch 34/500 => Train Loss: 0.6916, Train Acc: 0.8513, Val Loss: 0.8573, Val Acc: 0.7899
# Epoch 35/500 => Train Loss: 0.6799, Train Acc: 0.8672, Val Loss: 0.6172, Val Acc: 0.8911
# Epoch 36/500 => Train Loss: 0.6648, Train Acc: 0.8638, Val Loss: 0.5846, Val Acc: 0.8872
# Epoch 37/500 => Train Loss: 0.6659, Train Acc: 0.8722, Val Loss: 0.5375, Val Acc: 0.9222
# Epoch 38/500 => Train Loss: 0.6463, Train Acc: 0.8755, Val Loss: 0.5541, Val Acc: 0.9416
# Epoch 39/500 => Train Loss: 0.6488, Train Acc: 0.8822, Val Loss: 0.5390, Val Acc: 0.9105
# Epoch 40/500 => Train Loss: 0.6638, Train Acc: 0.8630, Val Loss: 0.5573, Val Acc: 0.9183
# Epoch 41/500 => Train Loss: 0.6758, Train Acc: 0.8622, Val Loss: 0.5477, Val Acc: 0.8988
# Epoch 42/500 => Train Loss: 0.6559, Train Acc: 0.8797, Val Loss: 0.5471, Val Acc: 0.9416
# Epoch 43/500 => Train Loss: 0.6600, Train Acc: 0.8705, Val Loss: 0.5656, Val Acc: 0.9144
# Epoch 44/500 => Train Loss: 0.6467, Train Acc: 0.8755, Val Loss: 0.5403, Val Acc: 0.9222
# Epoch 45/500 => Train Loss: 0.6480, Train Acc: 0.8772, Val Loss: 0.5911, Val Acc: 0.9027
# Epoch 46/500 => Train Loss: 0.6301, Train Acc: 0.8889, Val Loss: 0.5781, Val Acc: 0.9144
# Epoch 47/500 => Train Loss: 0.6352, Train Acc: 0.8864, Val Loss: 0.5392, Val Acc: 0.9416
# Epoch 48/500 => Train Loss: 0.6410, Train Acc: 0.8780, Val Loss: 0.5777, Val Acc: 0.9300
# Epoch 49/500 => Train Loss: 0.6512, Train Acc: 0.8931, Val Loss: 0.5274, Val Acc: 0.9455
# Epoch 50/500 => Train Loss: 0.6269, Train Acc: 0.8922, Val Loss: 0.5665, Val Acc: 0.8988
# Epoch 51/500 => Train Loss: 0.6254, Train Acc: 0.8864, Val Loss: 0.5774, Val Acc: 0.8911
# Epoch 52/500 => Train Loss: 0.6200, Train Acc: 0.8989, Val Loss: 0.5182, Val Acc: 0.9416
# Epoch 53/500 => Train Loss: 0.6120, Train Acc: 0.8997, Val Loss: 0.5580, Val Acc: 0.9066
# Epoch 54/500 => Train Loss: 0.6284, Train Acc: 0.8897, Val Loss: 0.5395, Val Acc: 0.9416
# Epoch 55/500 => Train Loss: 0.6159, Train Acc: 0.8972, Val Loss: 0.5335, Val Acc: 0.9339
# Epoch 56/500 => Train Loss: 0.6124, Train Acc: 0.9081, Val Loss: 0.5319, Val Acc: 0.9261
# Epoch 57/500 => Train Loss: 0.6188, Train Acc: 0.9039, Val Loss: 0.5375, Val Acc: 0.9300
# Epoch 58/500 => Train Loss: 0.6475, Train Acc: 0.8839, Val Loss: 0.5262, Val Acc: 0.9300
# Epoch 59/500 => Train Loss: 0.6104, Train Acc: 0.9006, Val Loss: 0.5169, Val Acc: 0.9416
# Epoch 60/500 => Train Loss: 0.6173, Train Acc: 0.8947, Val Loss: 0.5306, Val Acc: 0.9377
# Epoch 61/500 => Train Loss: 0.6352, Train Acc: 0.8964, Val Loss: 0.5233, Val Acc: 0.9533
# Epoch 62/500 => Train Loss: 0.6089, Train Acc: 0.8997, Val Loss: 0.5091, Val Acc: 0.9377
# Epoch 63/500 => Train Loss: 0.5828, Train Acc: 0.9140, Val Loss: 0.4935, Val Acc: 0.9572
# Epoch 64/500 => Train Loss: 0.6192, Train Acc: 0.8997, Val Loss: 0.5354, Val Acc: 0.9339
# Epoch 65/500 => Train Loss: 0.6101, Train Acc: 0.9073, Val Loss: 0.4988, Val Acc: 0.9494
# Epoch 66/500 => Train Loss: 0.6114, Train Acc: 0.9031, Val Loss: 0.5509, Val Acc: 0.9261
# Epoch 67/500 => Train Loss: 0.5948, Train Acc: 0.9156, Val Loss: 0.5096, Val Acc: 0.9572
# Epoch 68/500 => Train Loss: 0.5911, Train Acc: 0.9123, Val Loss: 0.5054, Val Acc: 0.9572
# Epoch 69/500 => Train Loss: 0.5922, Train Acc: 0.9073, Val Loss: 0.4975, Val Acc: 0.9533
# Epoch 70/500 => Train Loss: 0.6102, Train Acc: 0.9081, Val Loss: 0.5195, Val Acc: 0.9377
# Epoch 71/500 => Train Loss: 0.6005, Train Acc: 0.9106, Val Loss: 0.5317, Val Acc: 0.9339
# Epoch 72/500 => Train Loss: 0.6151, Train Acc: 0.8997, Val Loss: 0.5124, Val Acc: 0.9377
# Epoch 73/500 => Train Loss: 0.6168, Train Acc: 0.8981, Val Loss: 0.5331, Val Acc: 0.9261
# Epoch 74/500 => Train Loss: 0.5831, Train Acc: 0.9123, Val Loss: 0.5074, Val Acc: 0.9455
# Epoch 75/500 => Train Loss: 0.5793, Train Acc: 0.9181, Val Loss: 0.5144, Val Acc: 0.9455
# Epoch 76/500 => Train Loss: 0.5734, Train Acc: 0.9198, Val Loss: 0.4981, Val Acc: 0.9650
# Epoch 77/500 => Train Loss: 0.5831, Train Acc: 0.9165, Val Loss: 0.4877, Val Acc: 0.9650
# Epoch 78/500 => Train Loss: 0.5893, Train Acc: 0.9198, Val Loss: 0.5258, Val Acc: 0.9300
# Epoch 79/500 => Train Loss: 0.5805, Train Acc: 0.9248, Val Loss: 0.5030, Val Acc: 0.9494
# Epoch 80/500 => Train Loss: 0.5805, Train Acc: 0.9298, Val Loss: 0.5206, Val Acc: 0.9455
# Epoch 81/500 => Train Loss: 0.5820, Train Acc: 0.9148, Val Loss: 0.4862, Val Acc: 0.9611
# Epoch 82/500 => Train Loss: 0.5972, Train Acc: 0.9048, Val Loss: 0.5294, Val Acc: 0.9222
# Epoch 83/500 => Train Loss: 0.5726, Train Acc: 0.9156, Val Loss: 0.5306, Val Acc: 0.9339
# Epoch 84/500 => Train Loss: 0.5565, Train Acc: 0.9440, Val Loss: 0.5329, Val Acc: 0.9339
# Epoch 85/500 => Train Loss: 0.5752, Train Acc: 0.9198, Val Loss: 0.5315, Val Acc: 0.9533
# Epoch 86/500 => Train Loss: 0.5805, Train Acc: 0.9173, Val Loss: 0.4841, Val Acc: 0.9494
# Epoch 87/500 => Train Loss: 0.5836, Train Acc: 0.9173, Val Loss: 0.5321, Val Acc: 0.9416
# Epoch 88/500 => Train Loss: 0.5807, Train Acc: 0.9206, Val Loss: 0.5093, Val Acc: 0.9377
# Epoch 89/500 => Train Loss: 0.6062, Train Acc: 0.9089, Val Loss: 0.4694, Val Acc: 0.9689
# Epoch 90/500 => Train Loss: 0.5732, Train Acc: 0.9298, Val Loss: 0.4601, Val Acc: 0.9689
# Epoch 91/500 => Train Loss: 0.5733, Train Acc: 0.9223, Val Loss: 0.4954, Val Acc: 0.9494
# Epoch 92/500 => Train Loss: 0.5644, Train Acc: 0.9315, Val Loss: 0.4799, Val Acc: 0.9689
# Epoch 93/500 => Train Loss: 0.5708, Train Acc: 0.9240, Val Loss: 0.5601, Val Acc: 0.9377
# Epoch 94/500 => Train Loss: 0.5701, Train Acc: 0.9198, Val Loss: 0.5144, Val Acc: 0.9416
# Epoch 95/500 => Train Loss: 0.5734, Train Acc: 0.9240, Val Loss: 0.5239, Val Acc: 0.9416
# Epoch 96/500 => Train Loss: 0.5781, Train Acc: 0.9248, Val Loss: 0.5482, Val Acc: 0.9416
# Epoch 97/500 => Train Loss: 0.5639, Train Acc: 0.9298, Val Loss: 0.4903, Val Acc: 0.9611
# Epoch 98/500 => Train Loss: 0.5600, Train Acc: 0.9332, Val Loss: 0.4813, Val Acc: 0.9611
# Epoch 99/500 => Train Loss: 0.5503, Train Acc: 0.9432, Val Loss: 0.4827, Val Acc: 0.9650
# Epoch 100/500 => Train Loss: 0.5623, Train Acc: 0.9307, Val Loss: 0.5259, Val Acc: 0.9416
# Epoch 101/500 => Train Loss: 0.5826, Train Acc: 0.9156, Val Loss: 0.4876, Val Acc: 0.9572
# Epoch 102/500 => Train Loss: 0.5664, Train Acc: 0.9215, Val Loss: 0.4869, Val Acc: 0.9533
# Epoch 103/500 => Train Loss: 0.5678, Train Acc: 0.9282, Val Loss: 0.4955, Val Acc: 0.9728
# Epoch 104/500 => Train Loss: 0.5742, Train Acc: 0.9106, Val Loss: 0.4882, Val Acc: 0.9533
# Epoch 105/500 => Train Loss: 0.5490, Train Acc: 0.9332, Val Loss: 0.4994, Val Acc: 0.9533
# Epoch 106/500 => Train Loss: 0.5756, Train Acc: 0.9223, Val Loss: 0.4624, Val Acc: 0.9650
# Epoch 107/500 => Train Loss: 0.5639, Train Acc: 0.9223, Val Loss: 0.5111, Val Acc: 0.9416
# Epoch 108/500 => Train Loss: 0.5594, Train Acc: 0.9323, Val Loss: 0.4908, Val Acc: 0.9533
# Epoch 109/500 => Train Loss: 0.5642, Train Acc: 0.9323, Val Loss: 0.4932, Val Acc: 0.9416
# Epoch 110/500 => Train Loss: 0.5701, Train Acc: 0.9165, Val Loss: 0.4957, Val Acc: 0.9416
# Epoch 111/500 => Train Loss: 0.5437, Train Acc: 0.9449, Val Loss: 0.4957, Val Acc: 0.9533
# Epoch 112/500 => Train Loss: 0.5503, Train Acc: 0.9373, Val Loss: 0.4921, Val Acc: 0.9494
# Epoch 113/500 => Train Loss: 0.5326, Train Acc: 0.9440, Val Loss: 0.4874, Val Acc: 0.9455
# Epoch 114/500 => Train Loss: 0.5594, Train Acc: 0.9240, Val Loss: 0.4646, Val Acc: 0.9728
# Epoch 115/500 => Train Loss: 0.5317, Train Acc: 0.9499, Val Loss: 0.4779, Val Acc: 0.9728
# Epoch 116/500 => Train Loss: 0.5311, Train Acc: 0.9524, Val Loss: 0.5105, Val Acc: 0.9494
# Epoch 117/500 => Train Loss: 0.5601, Train Acc: 0.9282, Val Loss: 0.4933, Val Acc: 0.9572
# Epoch 118/500 => Train Loss: 0.5323, Train Acc: 0.9532, Val Loss: 0.4531, Val Acc: 0.9689
# Epoch 119/500 => Train Loss: 0.5605, Train Acc: 0.9307, Val Loss: 0.4904, Val Acc: 0.9611
# Epoch 120/500 => Train Loss: 0.5524, Train Acc: 0.9415, Val Loss: 0.4864, Val Acc: 0.9533
# Epoch 121/500 => Train Loss: 0.5691, Train Acc: 0.9198, Val Loss: 0.4543, Val Acc: 0.9650
# Epoch 122/500 => Train Loss: 0.5508, Train Acc: 0.9348, Val Loss: 0.4732, Val Acc: 0.9611
# Epoch 123/500 => Train Loss: 0.5525, Train Acc: 0.9340, Val Loss: 0.4994, Val Acc: 0.9416
# Epoch 124/500 => Train Loss: 0.5500, Train Acc: 0.9465, Val Loss: 0.5205, Val Acc: 0.9494
# Epoch 125/500 => Train Loss: 0.5320, Train Acc: 0.9449, Val Loss: 0.4823, Val Acc: 0.9494
# Epoch 126/500 => Train Loss: 0.5434, Train Acc: 0.9457, Val Loss: 0.4689, Val Acc: 0.9611
# Epoch 127/500 => Train Loss: 0.5519, Train Acc: 0.9357, Val Loss: 0.4835, Val Acc: 0.9611
# Epoch 128/500 => Train Loss: 0.5485, Train Acc: 0.9407, Val Loss: 0.4511, Val Acc: 0.9689
# Epoch 129/500 => Train Loss: 0.5393, Train Acc: 0.9515, Val Loss: 0.4681, Val Acc: 0.9767
# Epoch 130/500 => Train Loss: 0.5304, Train Acc: 0.9449, Val Loss: 0.4418, Val Acc: 0.9767
# Epoch 131/500 => Train Loss: 0.5243, Train Acc: 0.9549, Val Loss: 0.4644, Val Acc: 0.9611
# Epoch 132/500 => Train Loss: 0.5498, Train Acc: 0.9390, Val Loss: 0.4633, Val Acc: 0.9611
# Epoch 133/500 => Train Loss: 0.5484, Train Acc: 0.9390, Val Loss: 0.4831, Val Acc: 0.9611
# Epoch 134/500 => Train Loss: 0.5290, Train Acc: 0.9566, Val Loss: 0.4585, Val Acc: 0.9533
# Epoch 135/500 => Train Loss: 0.5353, Train Acc: 0.9490, Val Loss: 0.4700, Val Acc: 0.9650
# Epoch 136/500 => Train Loss: 0.5444, Train Acc: 0.9373, Val Loss: 0.4519, Val Acc: 0.9767
# Epoch 137/500 => Train Loss: 0.5336, Train Acc: 0.9499, Val Loss: 0.4496, Val Acc: 0.9611
# Epoch 138/500 => Train Loss: 0.5233, Train Acc: 0.9549, Val Loss: 0.4766, Val Acc: 0.9611
# Epoch 139/500 => Train Loss: 0.5210, Train Acc: 0.9532, Val Loss: 0.4494, Val Acc: 0.9728
# Epoch 140/500 => Train Loss: 0.5220, Train Acc: 0.9524, Val Loss: 0.4503, Val Acc: 0.9767
# Epoch 141/500 => Train Loss: 0.5328, Train Acc: 0.9424, Val Loss: 0.4875, Val Acc: 0.9611
# Epoch 142/500 => Train Loss: 0.5271, Train Acc: 0.9507, Val Loss: 0.4544, Val Acc: 0.9572
# Epoch 143/500 => Train Loss: 0.5266, Train Acc: 0.9515, Val Loss: 0.4881, Val Acc: 0.9533
# Epoch 144/500 => Train Loss: 0.5350, Train Acc: 0.9407, Val Loss: 0.4535, Val Acc: 0.9650
# Epoch 145/500 => Train Loss: 0.5187, Train Acc: 0.9607, Val Loss: 0.4674, Val Acc: 0.9689
# Epoch 146/500 => Train Loss: 0.5261, Train Acc: 0.9482, Val Loss: 0.4998, Val Acc: 0.9650
# Epoch 147/500 => Train Loss: 0.5223, Train Acc: 0.9515, Val Loss: 0.4908, Val Acc: 0.9494
# Epoch 148/500 => Train Loss: 0.5362, Train Acc: 0.9373, Val Loss: 0.4810, Val Acc: 0.9689
# Epoch 149/500 => Train Loss: 0.5475, Train Acc: 0.9373, Val Loss: 0.4607, Val Acc: 0.9650
# Epoch 150/500 => Train Loss: 0.5266, Train Acc: 0.9515, Val Loss: 0.4534, Val Acc: 0.9689
# Epoch 151/500 => Train Loss: 0.5312, Train Acc: 0.9490, Val Loss: 0.4752, Val Acc: 0.9611
# Epoch 152/500 => Train Loss: 0.5249, Train Acc: 0.9532, Val Loss: 0.4835, Val Acc: 0.9689
# Epoch 153/500 => Train Loss: 0.5223, Train Acc: 0.9566, Val Loss: 0.4606, Val Acc: 0.9767
# Epoch 154/500 => Train Loss: 0.5249, Train Acc: 0.9557, Val Loss: 0.4636, Val Acc: 0.9572
# Epoch 155/500 => Train Loss: 0.5455, Train Acc: 0.9307, Val Loss: 0.5089, Val Acc: 0.9533
# Epoch 156/500 => Train Loss: 0.5333, Train Acc: 0.9490, Val Loss: 0.4448, Val Acc: 0.9767
# Epoch 157/500 => Train Loss: 0.5263, Train Acc: 0.9457, Val Loss: 0.4662, Val Acc: 0.9728
# Epoch 158/500 => Train Loss: 0.5368, Train Acc: 0.9398, Val Loss: 0.5188, Val Acc: 0.9533
# Epoch 159/500 => Train Loss: 0.5212, Train Acc: 0.9474, Val Loss: 0.4770, Val Acc: 0.9650
# Epoch 160/500 => Train Loss: 0.5434, Train Acc: 0.9357, Val Loss: 0.4512, Val Acc: 0.9689
# Epoch 161/500 => Train Loss: 0.5154, Train Acc: 0.9541, Val Loss: 0.4597, Val Acc: 0.9728
# Epoch 162/500 => Train Loss: 0.5135, Train Acc: 0.9582, Val Loss: 0.4712, Val Acc: 0.9494
# Epoch 163/500 => Train Loss: 0.5356, Train Acc: 0.9424, Val Loss: 0.4683, Val Acc: 0.9650
# Epoch 164/500 => Train Loss: 0.5235, Train Acc: 0.9566, Val Loss: 0.4762, Val Acc: 0.9767
# Epoch 165/500 => Train Loss: 0.5279, Train Acc: 0.9482, Val Loss: 0.4823, Val Acc: 0.9650
# Epoch 166/500 => Train Loss: 0.5314, Train Acc: 0.9482, Val Loss: 0.4491, Val Acc: 0.9767
# Epoch 167/500 => Train Loss: 0.5190, Train Acc: 0.9482, Val Loss: 0.4441, Val Acc: 0.9728
# Epoch 168/500 => Train Loss: 0.5117, Train Acc: 0.9524, Val Loss: 0.4741, Val Acc: 0.9689
# Epoch 169/500 => Train Loss: 0.5149, Train Acc: 0.9549, Val Loss: 0.4322, Val Acc: 0.9728
# Epoch 170/500 => Train Loss: 0.5133, Train Acc: 0.9524, Val Loss: 0.4435, Val Acc: 0.9728
# Epoch 171/500 => Train Loss: 0.5078, Train Acc: 0.9616, Val Loss: 0.4533, Val Acc: 0.9728
# Epoch 172/500 => Train Loss: 0.5040, Train Acc: 0.9641, Val Loss: 0.4643, Val Acc: 0.9728
# Epoch 173/500 => Train Loss: 0.5145, Train Acc: 0.9607, Val Loss: 0.4640, Val Acc: 0.9767
# Epoch 174/500 => Train Loss: 0.5188, Train Acc: 0.9557, Val Loss: 0.4434, Val Acc: 0.9728
# Epoch 175/500 => Train Loss: 0.5106, Train Acc: 0.9599, Val Loss: 0.4460, Val Acc: 0.9767
# Epoch 176/500 => Train Loss: 0.5025, Train Acc: 0.9649, Val Loss: 0.4432, Val Acc: 0.9650
# Epoch 177/500 => Train Loss: 0.4995, Train Acc: 0.9641, Val Loss: 0.4821, Val Acc: 0.9689
# Epoch 178/500 => Train Loss: 0.5054, Train Acc: 0.9616, Val Loss: 0.4586, Val Acc: 0.9650
# Epoch 179/500 => Train Loss: 0.5224, Train Acc: 0.9499, Val Loss: 0.4579, Val Acc: 0.9650
# Epoch 180/500 => Train Loss: 0.5272, Train Acc: 0.9499, Val Loss: 0.4645, Val Acc: 0.9689
# Epoch 181/500 => Train Loss: 0.5192, Train Acc: 0.9532, Val Loss: 0.4606, Val Acc: 0.9767
# Epoch 182/500 => Train Loss: 0.5230, Train Acc: 0.9474, Val Loss: 0.4643, Val Acc: 0.9767
# Epoch 183/500 => Train Loss: 0.5128, Train Acc: 0.9591, Val Loss: 0.4265, Val Acc: 0.9728
# Epoch 184/500 => Train Loss: 0.5045, Train Acc: 0.9641, Val Loss: 0.4464, Val Acc: 0.9650
# Epoch 185/500 => Train Loss: 0.5115, Train Acc: 0.9524, Val Loss: 0.4433, Val Acc: 0.9689
# Epoch 186/500 => Train Loss: 0.5207, Train Acc: 0.9591, Val Loss: 0.4721, Val Acc: 0.9767
# Epoch 187/500 => Train Loss: 0.5193, Train Acc: 0.9515, Val Loss: 0.4435, Val Acc: 0.9728
# Epoch 188/500 => Train Loss: 0.5003, Train Acc: 0.9649, Val Loss: 0.4334, Val Acc: 0.9767
# Epoch 189/500 => Train Loss: 0.5089, Train Acc: 0.9574, Val Loss: 0.4530, Val Acc: 0.9728
# Epoch 190/500 => Train Loss: 0.5193, Train Acc: 0.9557, Val Loss: 0.4336, Val Acc: 0.9767
# Epoch 191/500 => Train Loss: 0.4994, Train Acc: 0.9657, Val Loss: 0.4397, Val Acc: 0.9728
# Epoch 192/500 => Train Loss: 0.5024, Train Acc: 0.9657, Val Loss: 0.4409, Val Acc: 0.9767
# Epoch 193/500 => Train Loss: 0.4975, Train Acc: 0.9599, Val Loss: 0.4508, Val Acc: 0.9728
# Epoch 194/500 => Train Loss: 0.5091, Train Acc: 0.9632, Val Loss: 0.4909, Val Acc: 0.9533
# Epoch 195/500 => Train Loss: 0.5087, Train Acc: 0.9649, Val Loss: 0.4309, Val Acc: 0.9767
# Epoch 196/500 => Train Loss: 0.5098, Train Acc: 0.9599, Val Loss: 0.4512, Val Acc: 0.9689
# Epoch 197/500 => Train Loss: 0.4995, Train Acc: 0.9632, Val Loss: 0.4605, Val Acc: 0.9728
# Epoch 198/500 => Train Loss: 0.5138, Train Acc: 0.9591, Val Loss: 0.4349, Val Acc: 0.9689
# Epoch 199/500 => Train Loss: 0.4948, Train Acc: 0.9691, Val Loss: 0.4134, Val Acc: 0.9728
# Epoch 200/500 => Train Loss: 0.5066, Train Acc: 0.9657, Val Loss: 0.4347, Val Acc: 0.9844
# Epoch 201/500 => Train Loss: 0.4976, Train Acc: 0.9666, Val Loss: 0.4775, Val Acc: 0.9689
# Epoch 202/500 => Train Loss: 0.4959, Train Acc: 0.9699, Val Loss: 0.4332, Val Acc: 0.9767
# Epoch 203/500 => Train Loss: 0.4963, Train Acc: 0.9632, Val Loss: 0.4558, Val Acc: 0.9728
# Epoch 204/500 => Train Loss: 0.5132, Train Acc: 0.9549, Val Loss: 0.4258, Val Acc: 0.9728
# Epoch 205/500 => Train Loss: 0.5125, Train Acc: 0.9574, Val Loss: 0.4634, Val Acc: 0.9611
# Epoch 206/500 => Train Loss: 0.5066, Train Acc: 0.9649, Val Loss: 0.5277, Val Acc: 0.9455
# Epoch 207/500 => Train Loss: 0.5003, Train Acc: 0.9641, Val Loss: 0.4322, Val Acc: 0.9767
# Epoch 208/500 => Train Loss: 0.5002, Train Acc: 0.9657, Val Loss: 0.4353, Val Acc: 0.9728
# Epoch 209/500 => Train Loss: 0.5007, Train Acc: 0.9691, Val Loss: 0.4209, Val Acc: 0.9767
# Epoch 210/500 => Train Loss: 0.4976, Train Acc: 0.9641, Val Loss: 0.4421, Val Acc: 0.9728
# Epoch 211/500 => Train Loss: 0.4924, Train Acc: 0.9674, Val Loss: 0.4145, Val Acc: 0.9883
# Epoch 212/500 => Train Loss: 0.4939, Train Acc: 0.9674, Val Loss: 0.4305, Val Acc: 0.9728
# Epoch 213/500 => Train Loss: 0.4935, Train Acc: 0.9749, Val Loss: 0.4365, Val Acc: 0.9767
# Epoch 214/500 => Train Loss: 0.5051, Train Acc: 0.9574, Val Loss: 0.4409, Val Acc: 0.9728
# Epoch 215/500 => Train Loss: 0.4968, Train Acc: 0.9632, Val Loss: 0.4505, Val Acc: 0.9689
# Epoch 216/500 => Train Loss: 0.4960, Train Acc: 0.9766, Val Loss: 0.4375, Val Acc: 0.9689
# Epoch 217/500 => Train Loss: 0.4986, Train Acc: 0.9666, Val Loss: 0.4508, Val Acc: 0.9805
# Epoch 218/500 => Train Loss: 0.4875, Train Acc: 0.9716, Val Loss: 0.4860, Val Acc: 0.9611
# Epoch 219/500 => Train Loss: 0.4975, Train Acc: 0.9616, Val Loss: 0.4437, Val Acc: 0.9689
# Epoch 220/500 => Train Loss: 0.4895, Train Acc: 0.9699, Val Loss: 0.4643, Val Acc: 0.9689
# Epoch 221/500 => Train Loss: 0.4947, Train Acc: 0.9657, Val Loss: 0.4347, Val Acc: 0.9767
# Epoch 222/500 => Train Loss: 0.4987, Train Acc: 0.9599, Val Loss: 0.4558, Val Acc: 0.9689
# Epoch 223/500 => Train Loss: 0.4965, Train Acc: 0.9691, Val Loss: 0.4380, Val Acc: 0.9805
# Epoch 224/500 => Train Loss: 0.4914, Train Acc: 0.9683, Val Loss: 0.4407, Val Acc: 0.9767
# Epoch 225/500 => Train Loss: 0.4924, Train Acc: 0.9691, Val Loss: 0.4293, Val Acc: 0.9805
# Epoch 226/500 => Train Loss: 0.4949, Train Acc: 0.9683, Val Loss: 0.4430, Val Acc: 0.9767
# Epoch 227/500 => Train Loss: 0.5007, Train Acc: 0.9632, Val Loss: 0.4466, Val Acc: 0.9650
# Epoch 228/500 => Train Loss: 0.5031, Train Acc: 0.9666, Val Loss: 0.4248, Val Acc: 0.9689
# Epoch 229/500 => Train Loss: 0.4926, Train Acc: 0.9708, Val Loss: 0.4232, Val Acc: 0.9767
# Epoch 230/500 => Train Loss: 0.4906, Train Acc: 0.9733, Val Loss: 0.4467, Val Acc: 0.9728
# Epoch 231/500 => Train Loss: 0.4912, Train Acc: 0.9691, Val Loss: 0.4468, Val Acc: 0.9689
# Epoch 232/500 => Train Loss: 0.4944, Train Acc: 0.9741, Val Loss: 0.4258, Val Acc: 0.9728
# Epoch 233/500 => Train Loss: 0.4924, Train Acc: 0.9649, Val Loss: 0.4689, Val Acc: 0.9689
# Epoch 234/500 => Train Loss: 0.4832, Train Acc: 0.9749, Val Loss: 0.4173, Val Acc: 0.9805
# Epoch 235/500 => Train Loss: 0.4848, Train Acc: 0.9716, Val Loss: 0.4369, Val Acc: 0.9728
# Epoch 236/500 => Train Loss: 0.4958, Train Acc: 0.9632, Val Loss: 0.4498, Val Acc: 0.9689
# Epoch 237/500 => Train Loss: 0.4894, Train Acc: 0.9716, Val Loss: 0.4338, Val Acc: 0.9767
# Epoch 238/500 => Train Loss: 0.4799, Train Acc: 0.9716, Val Loss: 0.4175, Val Acc: 0.9805
# Epoch 239/500 => Train Loss: 0.4876, Train Acc: 0.9708, Val Loss: 0.4394, Val Acc: 0.9728
# Epoch 240/500 => Train Loss: 0.4826, Train Acc: 0.9716, Val Loss: 0.4168, Val Acc: 0.9767
# Epoch 241/500 => Train Loss: 0.4986, Train Acc: 0.9657, Val Loss: 0.4711, Val Acc: 0.9689
# Epoch 242/500 => Train Loss: 0.4837, Train Acc: 0.9758, Val Loss: 0.4328, Val Acc: 0.9767
# Epoch 243/500 => Train Loss: 0.5030, Train Acc: 0.9632, Val Loss: 0.4554, Val Acc: 0.9689
# Epoch 244/500 => Train Loss: 0.5022, Train Acc: 0.9591, Val Loss: 0.4242, Val Acc: 0.9805
# Epoch 245/500 => Train Loss: 0.4969, Train Acc: 0.9632, Val Loss: 0.4476, Val Acc: 0.9728
# Epoch 246/500 => Train Loss: 0.4914, Train Acc: 0.9632, Val Loss: 0.4244, Val Acc: 0.9767
# Epoch 247/500 => Train Loss: 0.4735, Train Acc: 0.9749, Val Loss: 0.4057, Val Acc: 0.9805
# Epoch 248/500 => Train Loss: 0.4779, Train Acc: 0.9683, Val Loss: 0.4319, Val Acc: 0.9805
# Epoch 249/500 => Train Loss: 0.5029, Train Acc: 0.9649, Val Loss: 0.4693, Val Acc: 0.9689
# Epoch 250/500 => Train Loss: 0.4981, Train Acc: 0.9649, Val Loss: 0.4496, Val Acc: 0.9728
# Epoch 251/500 => Train Loss: 0.4828, Train Acc: 0.9716, Val Loss: 0.4281, Val Acc: 0.9767
# Epoch 252/500 => Train Loss: 0.4909, Train Acc: 0.9691, Val Loss: 0.4083, Val Acc: 0.9805
# Epoch 253/500 => Train Loss: 0.4921, Train Acc: 0.9691, Val Loss: 0.4348, Val Acc: 0.9728
# Epoch 254/500 => Train Loss: 0.4756, Train Acc: 0.9749, Val Loss: 0.4311, Val Acc: 0.9767
# Epoch 255/500 => Train Loss: 0.4853, Train Acc: 0.9691, Val Loss: 0.4142, Val Acc: 0.9767
# Epoch 256/500 => Train Loss: 0.4937, Train Acc: 0.9716, Val Loss: 0.4366, Val Acc: 0.9767
# Epoch 257/500 => Train Loss: 0.4859, Train Acc: 0.9666, Val Loss: 0.4281, Val Acc: 0.9767
# Epoch 258/500 => Train Loss: 0.4949, Train Acc: 0.9683, Val Loss: 0.4330, Val Acc: 0.9767
# Epoch 259/500 => Train Loss: 0.5049, Train Acc: 0.9582, Val Loss: 0.4398, Val Acc: 0.9650
# Epoch 260/500 => Train Loss: 0.5074, Train Acc: 0.9607, Val Loss: 0.4200, Val Acc: 0.9728
# Epoch 261/500 => Train Loss: 0.4854, Train Acc: 0.9691, Val Loss: 0.4485, Val Acc: 0.9728
# Epoch 262/500 => Train Loss: 0.4754, Train Acc: 0.9766, Val Loss: 0.4318, Val Acc: 0.9767
# Epoch 263/500 => Train Loss: 0.4848, Train Acc: 0.9699, Val Loss: 0.4147, Val Acc: 0.9767
# Epoch 264/500 => Train Loss: 0.4861, Train Acc: 0.9741, Val Loss: 0.4318, Val Acc: 0.9689
# Epoch 265/500 => Train Loss: 0.4840, Train Acc: 0.9783, Val Loss: 0.4359, Val Acc: 0.9767
# Epoch 266/500 => Train Loss: 0.4875, Train Acc: 0.9674, Val Loss: 0.4171, Val Acc: 0.9805
# Epoch 267/500 => Train Loss: 0.4806, Train Acc: 0.9791, Val Loss: 0.4331, Val Acc: 0.9689
# Epoch 268/500 => Train Loss: 0.4940, Train Acc: 0.9683, Val Loss: 0.4194, Val Acc: 0.9767
# Epoch 269/500 => Train Loss: 0.4947, Train Acc: 0.9708, Val Loss: 0.4390, Val Acc: 0.9767
# Epoch 270/500 => Train Loss: 0.4785, Train Acc: 0.9724, Val Loss: 0.4222, Val Acc: 0.9767
# Epoch 271/500 => Train Loss: 0.4689, Train Acc: 0.9791, Val Loss: 0.4138, Val Acc: 0.9728
# Epoch 272/500 => Train Loss: 0.4790, Train Acc: 0.9699, Val Loss: 0.4328, Val Acc: 0.9650
# Epoch 273/500 => Train Loss: 0.4804, Train Acc: 0.9733, Val Loss: 0.4197, Val Acc: 0.9767
# Epoch 274/500 => Train Loss: 0.4830, Train Acc: 0.9724, Val Loss: 0.4274, Val Acc: 0.9767
# Epoch 275/500 => Train Loss: 0.4902, Train Acc: 0.9674, Val Loss: 0.4252, Val Acc: 0.9767
# Epoch 276/500 => Train Loss: 0.4668, Train Acc: 0.9774, Val Loss: 0.4081, Val Acc: 0.9844
# Epoch 277/500 => Train Loss: 0.4953, Train Acc: 0.9616, Val Loss: 0.4179, Val Acc: 0.9728
# Epoch 278/500 => Train Loss: 0.4817, Train Acc: 0.9666, Val Loss: 0.4355, Val Acc: 0.9767
# Epoch 279/500 => Train Loss: 0.4747, Train Acc: 0.9808, Val Loss: 0.4169, Val Acc: 0.9767
# Epoch 280/500 => Train Loss: 0.4741, Train Acc: 0.9741, Val Loss: 0.4181, Val Acc: 0.9844
# Epoch 281/500 => Train Loss: 0.4729, Train Acc: 0.9758, Val Loss: 0.4160, Val Acc: 0.9844
# Epoch 282/500 => Train Loss: 0.4731, Train Acc: 0.9724, Val Loss: 0.4218, Val Acc: 0.9805
# Epoch 283/500 => Train Loss: 0.4857, Train Acc: 0.9716, Val Loss: 0.4212, Val Acc: 0.9728
# Epoch 284/500 => Train Loss: 0.4785, Train Acc: 0.9741, Val Loss: 0.4098, Val Acc: 0.9805
# Epoch 285/500 => Train Loss: 0.4809, Train Acc: 0.9699, Val Loss: 0.4170, Val Acc: 0.9844
# Epoch 286/500 => Train Loss: 0.4774, Train Acc: 0.9758, Val Loss: 0.4245, Val Acc: 0.9767
# Epoch 287/500 => Train Loss: 0.4714, Train Acc: 0.9816, Val Loss: 0.4252, Val Acc: 0.9883
# Epoch 288/500 => Train Loss: 0.4785, Train Acc: 0.9783, Val Loss: 0.4343, Val Acc: 0.9728
# Epoch 289/500 => Train Loss: 0.4722, Train Acc: 0.9783, Val Loss: 0.4164, Val Acc: 0.9728
# Epoch 290/500 => Train Loss: 0.4793, Train Acc: 0.9666, Val Loss: 0.4206, Val Acc: 0.9767
# Epoch 291/500 => Train Loss: 0.4789, Train Acc: 0.9816, Val Loss: 0.4392, Val Acc: 0.9728
# Epoch 292/500 => Train Loss: 0.4724, Train Acc: 0.9758, Val Loss: 0.4298, Val Acc: 0.9650
# Epoch 293/500 => Train Loss: 0.4972, Train Acc: 0.9641, Val Loss: 0.4271, Val Acc: 0.9728
# Epoch 294/500 => Train Loss: 0.4771, Train Acc: 0.9766, Val Loss: 0.4261, Val Acc: 0.9767
# Epoch 295/500 => Train Loss: 0.4812, Train Acc: 0.9749, Val Loss: 0.4108, Val Acc: 0.9883
# Epoch 296/500 => Train Loss: 0.4857, Train Acc: 0.9724, Val Loss: 0.4125, Val Acc: 0.9844
# Epoch 297/500 => Train Loss: 0.4726, Train Acc: 0.9791, Val Loss: 0.4065, Val Acc: 0.9805
# Epoch 298/500 => Train Loss: 0.4748, Train Acc: 0.9799, Val Loss: 0.4110, Val Acc: 0.9767
# Epoch 299/500 => Train Loss: 0.4805, Train Acc: 0.9716, Val Loss: 0.4143, Val Acc: 0.9728
# Epoch 300/500 => Train Loss: 0.4921, Train Acc: 0.9683, Val Loss: 0.4274, Val Acc: 0.9767
# Epoch 301/500 => Train Loss: 0.4663, Train Acc: 0.9808, Val Loss: 0.4170, Val Acc: 0.9767
# Epoch 302/500 => Train Loss: 0.4793, Train Acc: 0.9724, Val Loss: 0.4182, Val Acc: 0.9767
# Epoch 303/500 => Train Loss: 0.4830, Train Acc: 0.9741, Val Loss: 0.4489, Val Acc: 0.9611
# Epoch 304/500 => Train Loss: 0.4759, Train Acc: 0.9741, Val Loss: 0.4106, Val Acc: 0.9844
# Epoch 305/500 => Train Loss: 0.4623, Train Acc: 0.9866, Val Loss: 0.4024, Val Acc: 0.9883
# Epoch 306/500 => Train Loss: 0.4635, Train Acc: 0.9833, Val Loss: 0.4068, Val Acc: 0.9805
# Epoch 307/500 => Train Loss: 0.4739, Train Acc: 0.9816, Val Loss: 0.4235, Val Acc: 0.9767
# Epoch 308/500 => Train Loss: 0.4803, Train Acc: 0.9699, Val Loss: 0.4187, Val Acc: 0.9728
# Epoch 309/500 => Train Loss: 0.4811, Train Acc: 0.9766, Val Loss: 0.4174, Val Acc: 0.9767
# Epoch 310/500 => Train Loss: 0.4823, Train Acc: 0.9741, Val Loss: 0.4493, Val Acc: 0.9728
# Epoch 311/500 => Train Loss: 0.4824, Train Acc: 0.9766, Val Loss: 0.4025, Val Acc: 0.9844
# Epoch 312/500 => Train Loss: 0.4702, Train Acc: 0.9766, Val Loss: 0.4179, Val Acc: 0.9805
# Epoch 313/500 => Train Loss: 0.4876, Train Acc: 0.9708, Val Loss: 0.4243, Val Acc: 0.9689
# Epoch 314/500 => Train Loss: 0.4736, Train Acc: 0.9833, Val Loss: 0.4210, Val Acc: 0.9883
# Epoch 315/500 => Train Loss: 0.4792, Train Acc: 0.9741, Val Loss: 0.4224, Val Acc: 0.9844
# Epoch 316/500 => Train Loss: 0.4715, Train Acc: 0.9749, Val Loss: 0.4226, Val Acc: 0.9728
# Epoch 317/500 => Train Loss: 0.4779, Train Acc: 0.9741, Val Loss: 0.4146, Val Acc: 0.9767
# Epoch 318/500 => Train Loss: 0.4758, Train Acc: 0.9783, Val Loss: 0.4264, Val Acc: 0.9728
# Epoch 319/500 => Train Loss: 0.4705, Train Acc: 0.9858, Val Loss: 0.4261, Val Acc: 0.9767
# Epoch 320/500 => Train Loss: 0.4764, Train Acc: 0.9733, Val Loss: 0.4025, Val Acc: 0.9844
# Epoch 321/500 => Train Loss: 0.4696, Train Acc: 0.9774, Val Loss: 0.4094, Val Acc: 0.9844
# Epoch 322/500 => Train Loss: 0.4774, Train Acc: 0.9791, Val Loss: 0.4113, Val Acc: 0.9805
# Epoch 323/500 => Train Loss: 0.4693, Train Acc: 0.9791, Val Loss: 0.4177, Val Acc: 0.9767
# Epoch 324/500 => Train Loss: 0.4709, Train Acc: 0.9808, Val Loss: 0.4140, Val Acc: 0.9844
# Epoch 325/500 => Train Loss: 0.4772, Train Acc: 0.9774, Val Loss: 0.4044, Val Acc: 0.9844
# Epoch 326/500 => Train Loss: 0.4658, Train Acc: 0.9841, Val Loss: 0.4045, Val Acc: 0.9805
# Epoch 327/500 => Train Loss: 0.4652, Train Acc: 0.9841, Val Loss: 0.4154, Val Acc: 0.9883
# Epoch 328/500 => Train Loss: 0.4683, Train Acc: 0.9791, Val Loss: 0.4041, Val Acc: 0.9767
# Epoch 329/500 => Train Loss: 0.4634, Train Acc: 0.9866, Val Loss: 0.4043, Val Acc: 0.9883
# Epoch 330/500 => Train Loss: 0.4698, Train Acc: 0.9774, Val Loss: 0.4610, Val Acc: 0.9650
# Epoch 331/500 => Train Loss: 0.4888, Train Acc: 0.9683, Val Loss: 0.4320, Val Acc: 0.9767
# Epoch 332/500 => Train Loss: 0.4767, Train Acc: 0.9799, Val Loss: 0.4224, Val Acc: 0.9728
# Epoch 333/500 => Train Loss: 0.4658, Train Acc: 0.9850, Val Loss: 0.4224, Val Acc: 0.9805
# Epoch 334/500 => Train Loss: 0.4742, Train Acc: 0.9749, Val Loss: 0.4292, Val Acc: 0.9728
# Epoch 335/500 => Train Loss: 0.4708, Train Acc: 0.9825, Val Loss: 0.4176, Val Acc: 0.9728
# Epoch 336/500 => Train Loss: 0.4747, Train Acc: 0.9758, Val Loss: 0.4244, Val Acc: 0.9689
# Epoch 337/500 => Train Loss: 0.4747, Train Acc: 0.9833, Val Loss: 0.4027, Val Acc: 0.9883
# Epoch 338/500 => Train Loss: 0.4701, Train Acc: 0.9783, Val Loss: 0.4299, Val Acc: 0.9728
# Epoch 339/500 => Train Loss: 0.4612, Train Acc: 0.9841, Val Loss: 0.4244, Val Acc: 0.9728
# Epoch 340/500 => Train Loss: 0.4778, Train Acc: 0.9774, Val Loss: 0.4351, Val Acc: 0.9844
# Epoch 341/500 => Train Loss: 0.4911, Train Acc: 0.9657, Val Loss: 0.4064, Val Acc: 0.9883
# Epoch 342/500 => Train Loss: 0.4762, Train Acc: 0.9691, Val Loss: 0.4213, Val Acc: 0.9728
# Epoch 343/500 => Train Loss: 0.4789, Train Acc: 0.9741, Val Loss: 0.4400, Val Acc: 0.9767
# Epoch 344/500 => Train Loss: 0.4717, Train Acc: 0.9766, Val Loss: 0.4201, Val Acc: 0.9689
# Epoch 345/500 => Train Loss: 0.4810, Train Acc: 0.9733, Val Loss: 0.4161, Val Acc: 0.9728
# Epoch 346/500 => Train Loss: 0.4670, Train Acc: 0.9766, Val Loss: 0.4027, Val Acc: 0.9883
# Epoch 347/500 => Train Loss: 0.4799, Train Acc: 0.9766, Val Loss: 0.4278, Val Acc: 0.9767
# Epoch 348/500 => Train Loss: 0.4828, Train Acc: 0.9749, Val Loss: 0.4331, Val Acc: 0.9767
# Epoch 349/500 => Train Loss: 0.4782, Train Acc: 0.9749, Val Loss: 0.4364, Val Acc: 0.9650
# Epoch 350/500 => Train Loss: 0.4820, Train Acc: 0.9716, Val Loss: 0.4167, Val Acc: 0.9805
# Epoch 351/500 => Train Loss: 0.4710, Train Acc: 0.9741, Val Loss: 0.4247, Val Acc: 0.9767
# Epoch 352/500 => Train Loss: 0.4726, Train Acc: 0.9741, Val Loss: 0.4101, Val Acc: 0.9805
# Epoch 353/500 => Train Loss: 0.4822, Train Acc: 0.9741, Val Loss: 0.4127, Val Acc: 0.9767
# Epoch 354/500 => Train Loss: 0.4753, Train Acc: 0.9808, Val Loss: 0.4378, Val Acc: 0.9689
# Epoch 355/500 => Train Loss: 0.4563, Train Acc: 0.9858, Val Loss: 0.4073, Val Acc: 0.9728
# Epoch 356/500 => Train Loss: 0.4639, Train Acc: 0.9791, Val Loss: 0.4325, Val Acc: 0.9767
# Epoch 357/500 => Train Loss: 0.4695, Train Acc: 0.9833, Val Loss: 0.4235, Val Acc: 0.9728
# Epoch 358/500 => Train Loss: 0.4624, Train Acc: 0.9791, Val Loss: 0.3948, Val Acc: 0.9883
# Epoch 359/500 => Train Loss: 0.4682, Train Acc: 0.9783, Val Loss: 0.4299, Val Acc: 0.9767
# Epoch 360/500 => Train Loss: 0.4779, Train Acc: 0.9758, Val Loss: 0.4100, Val Acc: 0.9728
# Epoch 361/500 => Train Loss: 0.4721, Train Acc: 0.9766, Val Loss: 0.4052, Val Acc: 0.9883
# Epoch 362/500 => Train Loss: 0.4698, Train Acc: 0.9808, Val Loss: 0.4285, Val Acc: 0.9767
# Epoch 363/500 => Train Loss: 0.4631, Train Acc: 0.9825, Val Loss: 0.4090, Val Acc: 0.9844
# Epoch 364/500 => Train Loss: 0.4586, Train Acc: 0.9841, Val Loss: 0.4083, Val Acc: 0.9883
# Epoch 365/500 => Train Loss: 0.4600, Train Acc: 0.9791, Val Loss: 0.4313, Val Acc: 0.9728
# Epoch 366/500 => Train Loss: 0.4596, Train Acc: 0.9858, Val Loss: 0.4089, Val Acc: 0.9767
# Epoch 367/500 => Train Loss: 0.4638, Train Acc: 0.9833, Val Loss: 0.4102, Val Acc: 0.9728
# Epoch 368/500 => Train Loss: 0.4631, Train Acc: 0.9825, Val Loss: 0.4115, Val Acc: 0.9844
# Epoch 369/500 => Train Loss: 0.4816, Train Acc: 0.9749, Val Loss: 0.4075, Val Acc: 0.9767
# Epoch 370/500 => Train Loss: 0.4615, Train Acc: 0.9816, Val Loss: 0.4134, Val Acc: 0.9728
# Epoch 371/500 => Train Loss: 0.4593, Train Acc: 0.9833, Val Loss: 0.4068, Val Acc: 0.9805
# Epoch 372/500 => Train Loss: 0.4673, Train Acc: 0.9791, Val Loss: 0.4212, Val Acc: 0.9689
# Epoch 373/500 => Train Loss: 0.4656, Train Acc: 0.9774, Val Loss: 0.4319, Val Acc: 0.9728
# Epoch 374/500 => Train Loss: 0.4670, Train Acc: 0.9825, Val Loss: 0.4117, Val Acc: 0.9767
# Epoch 375/500 => Train Loss: 0.4646, Train Acc: 0.9783, Val Loss: 0.4056, Val Acc: 0.9728
# Epoch 376/500 => Train Loss: 0.4614, Train Acc: 0.9799, Val Loss: 0.4223, Val Acc: 0.9728
# Epoch 377/500 => Train Loss: 0.4684, Train Acc: 0.9741, Val Loss: 0.4106, Val Acc: 0.9767
# Epoch 378/500 => Train Loss: 0.4726, Train Acc: 0.9741, Val Loss: 0.4174, Val Acc: 0.9728
# Epoch 379/500 => Train Loss: 0.4666, Train Acc: 0.9816, Val Loss: 0.4446, Val Acc: 0.9689
# Epoch 380/500 => Train Loss: 0.4593, Train Acc: 0.9883, Val Loss: 0.4090, Val Acc: 0.9689
# Epoch 381/500 => Train Loss: 0.4709, Train Acc: 0.9816, Val Loss: 0.4281, Val Acc: 0.9689
# Epoch 382/500 => Train Loss: 0.4681, Train Acc: 0.9783, Val Loss: 0.4157, Val Acc: 0.9767
# Epoch 383/500 => Train Loss: 0.4647, Train Acc: 0.9783, Val Loss: 0.4153, Val Acc: 0.9844
# Epoch 384/500 => Train Loss: 0.4676, Train Acc: 0.9741, Val Loss: 0.4241, Val Acc: 0.9689
# Epoch 385/500 => Train Loss: 0.4639, Train Acc: 0.9774, Val Loss: 0.4316, Val Acc: 0.9728
# Epoch 386/500 => Train Loss: 0.4688, Train Acc: 0.9799, Val Loss: 0.4228, Val Acc: 0.9728
# Epoch 387/500 => Train Loss: 0.4669, Train Acc: 0.9875, Val Loss: 0.4211, Val Acc: 0.9767
# Epoch 388/500 => Train Loss: 0.4787, Train Acc: 0.9766, Val Loss: 0.4244, Val Acc: 0.9689
# Epoch 389/500 => Train Loss: 0.4613, Train Acc: 0.9850, Val Loss: 0.4242, Val Acc: 0.9728
# Epoch 390/500 => Train Loss: 0.4670, Train Acc: 0.9799, Val Loss: 0.4287, Val Acc: 0.9728
# Epoch 391/500 => Train Loss: 0.4602, Train Acc: 0.9816, Val Loss: 0.4375, Val Acc: 0.9689
# Epoch 392/500 => Train Loss: 0.4656, Train Acc: 0.9791, Val Loss: 0.4218, Val Acc: 0.9728
# Epoch 393/500 => Train Loss: 0.4588, Train Acc: 0.9825, Val Loss: 0.4348, Val Acc: 0.9728
# Epoch 394/500 => Train Loss: 0.4801, Train Acc: 0.9674, Val Loss: 0.4165, Val Acc: 0.9805
# Epoch 395/500 => Train Loss: 0.4659, Train Acc: 0.9799, Val Loss: 0.4190, Val Acc: 0.9767
# Epoch 396/500 => Train Loss: 0.4641, Train Acc: 0.9774, Val Loss: 0.4207, Val Acc: 0.9767
# Epoch 397/500 => Train Loss: 0.4657, Train Acc: 0.9816, Val Loss: 0.4182, Val Acc: 0.9689
# Epoch 398/500 => Train Loss: 0.4723, Train Acc: 0.9841, Val Loss: 0.4113, Val Acc: 0.9805
# Epoch 399/500 => Train Loss: 0.4649, Train Acc: 0.9883, Val Loss: 0.4084, Val Acc: 0.9767
# Epoch 400/500 => Train Loss: 0.4613, Train Acc: 0.9783, Val Loss: 0.4195, Val Acc: 0.9767
# Epoch 401/500 => Train Loss: 0.4548, Train Acc: 0.9858, Val Loss: 0.3992, Val Acc: 0.9805
# Epoch 402/500 => Train Loss: 0.4740, Train Acc: 0.9799, Val Loss: 0.4207, Val Acc: 0.9805
# Epoch 403/500 => Train Loss: 0.4661, Train Acc: 0.9808, Val Loss: 0.4319, Val Acc: 0.9728
# Epoch 404/500 => Train Loss: 0.4591, Train Acc: 0.9858, Val Loss: 0.4011, Val Acc: 0.9805
# Epoch 405/500 => Train Loss: 0.4581, Train Acc: 0.9816, Val Loss: 0.4024, Val Acc: 0.9805
# Epoch 406/500 => Train Loss: 0.4576, Train Acc: 0.9841, Val Loss: 0.4213, Val Acc: 0.9728
# Epoch 407/500 => Train Loss: 0.4650, Train Acc: 0.9808, Val Loss: 0.4341, Val Acc: 0.9728
# Epoch 408/500 => Train Loss: 0.4662, Train Acc: 0.9791, Val Loss: 0.4450, Val Acc: 0.9728
# Epoch 409/500 => Train Loss: 0.4757, Train Acc: 0.9716, Val Loss: 0.4288, Val Acc: 0.9728
# Epoch 410/500 => Train Loss: 0.4609, Train Acc: 0.9850, Val Loss: 0.4051, Val Acc: 0.9883
# Epoch 411/500 => Train Loss: 0.4602, Train Acc: 0.9799, Val Loss: 0.4008, Val Acc: 0.9805
# Epoch 412/500 => Train Loss: 0.4639, Train Acc: 0.9791, Val Loss: 0.4021, Val Acc: 0.9805
# Epoch 413/500 => Train Loss: 0.4583, Train Acc: 0.9850, Val Loss: 0.4118, Val Acc: 0.9767
# Epoch 414/500 => Train Loss: 0.4597, Train Acc: 0.9858, Val Loss: 0.4220, Val Acc: 0.9767
# Epoch 415/500 => Train Loss: 0.4509, Train Acc: 0.9816, Val Loss: 0.4077, Val Acc: 0.9844
# Epoch 416/500 => Train Loss: 0.4628, Train Acc: 0.9875, Val Loss: 0.4153, Val Acc: 0.9728
# Epoch 417/500 => Train Loss: 0.4594, Train Acc: 0.9875, Val Loss: 0.4220, Val Acc: 0.9767
# Epoch 418/500 => Train Loss: 0.4524, Train Acc: 0.9883, Val Loss: 0.4078, Val Acc: 0.9805
# Epoch 419/500 => Train Loss: 0.4620, Train Acc: 0.9841, Val Loss: 0.4024, Val Acc: 0.9767
# Epoch 420/500 => Train Loss: 0.4658, Train Acc: 0.9783, Val Loss: 0.4181, Val Acc: 0.9844
# Epoch 421/500 => Train Loss: 0.4655, Train Acc: 0.9825, Val Loss: 0.4080, Val Acc: 0.9767
# Epoch 422/500 => Train Loss: 0.4561, Train Acc: 0.9883, Val Loss: 0.4086, Val Acc: 0.9883
# Epoch 423/500 => Train Loss: 0.4566, Train Acc: 0.9875, Val Loss: 0.4156, Val Acc: 0.9767
# Epoch 424/500 => Train Loss: 0.4532, Train Acc: 0.9841, Val Loss: 0.4216, Val Acc: 0.9767
# Epoch 425/500 => Train Loss: 0.4632, Train Acc: 0.9833, Val Loss: 0.4185, Val Acc: 0.9767
# Epoch 426/500 => Train Loss: 0.4592, Train Acc: 0.9825, Val Loss: 0.4237, Val Acc: 0.9767
# Epoch 427/500 => Train Loss: 0.4573, Train Acc: 0.9841, Val Loss: 0.3972, Val Acc: 0.9883
# Epoch 428/500 => Train Loss: 0.4555, Train Acc: 0.9850, Val Loss: 0.4084, Val Acc: 0.9805
# Epoch 429/500 => Train Loss: 0.4581, Train Acc: 0.9833, Val Loss: 0.4214, Val Acc: 0.9767
# Epoch 430/500 => Train Loss: 0.4611, Train Acc: 0.9850, Val Loss: 0.4189, Val Acc: 0.9805
# Epoch 431/500 => Train Loss: 0.4708, Train Acc: 0.9808, Val Loss: 0.4242, Val Acc: 0.9767
# Epoch 432/500 => Train Loss: 0.4590, Train Acc: 0.9891, Val Loss: 0.4432, Val Acc: 0.9805
# Epoch 433/500 => Train Loss: 0.4519, Train Acc: 0.9883, Val Loss: 0.4148, Val Acc: 0.9805
# Epoch 434/500 => Train Loss: 0.4609, Train Acc: 0.9875, Val Loss: 0.4172, Val Acc: 0.9767
# Epoch 435/500 => Train Loss: 0.4577, Train Acc: 0.9841, Val Loss: 0.4380, Val Acc: 0.9689
# Epoch 436/500 => Train Loss: 0.4531, Train Acc: 0.9816, Val Loss: 0.4079, Val Acc: 0.9883
# Epoch 437/500 => Train Loss: 0.4549, Train Acc: 0.9858, Val Loss: 0.4130, Val Acc: 0.9767
# Epoch 438/500 => Train Loss: 0.4575, Train Acc: 0.9850, Val Loss: 0.4196, Val Acc: 0.9728
# Epoch 439/500 => Train Loss: 0.4601, Train Acc: 0.9816, Val Loss: 0.4140, Val Acc: 0.9883
# Epoch 440/500 => Train Loss: 0.4627, Train Acc: 0.9799, Val Loss: 0.4319, Val Acc: 0.9728
# Epoch 441/500 => Train Loss: 0.4504, Train Acc: 0.9908, Val Loss: 0.4075, Val Acc: 0.9767
# Epoch 442/500 => Train Loss: 0.4450, Train Acc: 0.9850, Val Loss: 0.4175, Val Acc: 0.9767
# Epoch 443/500 => Train Loss: 0.4483, Train Acc: 0.9891, Val Loss: 0.4116, Val Acc: 0.9805
# Epoch 444/500 => Train Loss: 0.4558, Train Acc: 0.9833, Val Loss: 0.4192, Val Acc: 0.9767
# Epoch 445/500 => Train Loss: 0.4460, Train Acc: 0.9891, Val Loss: 0.4074, Val Acc: 0.9767
# Epoch 446/500 => Train Loss: 0.4490, Train Acc: 0.9875, Val Loss: 0.3997, Val Acc: 0.9883
# Epoch 447/500 => Train Loss: 0.4640, Train Acc: 0.9791, Val Loss: 0.4214, Val Acc: 0.9767
# Epoch 448/500 => Train Loss: 0.4538, Train Acc: 0.9850, Val Loss: 0.4167, Val Acc: 0.9844
# Epoch 449/500 => Train Loss: 0.4488, Train Acc: 0.9900, Val Loss: 0.4098, Val Acc: 0.9805
# Epoch 450/500 => Train Loss: 0.4547, Train Acc: 0.9850, Val Loss: 0.4093, Val Acc: 0.9805
# Epoch 451/500 => Train Loss: 0.4514, Train Acc: 0.9908, Val Loss: 0.4290, Val Acc: 0.9767
# Epoch 452/500 => Train Loss: 0.4533, Train Acc: 0.9858, Val Loss: 0.4183, Val Acc: 0.9767
# Epoch 453/500 => Train Loss: 0.4523, Train Acc: 0.9916, Val Loss: 0.4115, Val Acc: 0.9844
# Epoch 454/500 => Train Loss: 0.4577, Train Acc: 0.9841, Val Loss: 0.4032, Val Acc: 0.9805
# Epoch 455/500 => Train Loss: 0.4541, Train Acc: 0.9799, Val Loss: 0.4080, Val Acc: 0.9883
# Epoch 456/500 => Train Loss: 0.4473, Train Acc: 0.9883, Val Loss: 0.4032, Val Acc: 0.9805
# Epoch 457/500 => Train Loss: 0.4601, Train Acc: 0.9816, Val Loss: 0.4101, Val Acc: 0.9805
# Epoch 458/500 => Train Loss: 0.4671, Train Acc: 0.9841, Val Loss: 0.4102, Val Acc: 0.9805
# Epoch 459/500 => Train Loss: 0.4633, Train Acc: 0.9808, Val Loss: 0.4081, Val Acc: 0.9805
# Epoch 460/500 => Train Loss: 0.4524, Train Acc: 0.9833, Val Loss: 0.4101, Val Acc: 0.9844
# Epoch 461/500 => Train Loss: 0.4455, Train Acc: 0.9908, Val Loss: 0.4077, Val Acc: 0.9844
# Epoch 462/500 => Train Loss: 0.4552, Train Acc: 0.9850, Val Loss: 0.4015, Val Acc: 0.9767
# Epoch 463/500 => Train Loss: 0.4541, Train Acc: 0.9799, Val Loss: 0.4346, Val Acc: 0.9767
# Epoch 464/500 => Train Loss: 0.4549, Train Acc: 0.9850, Val Loss: 0.4037, Val Acc: 0.9767
# Epoch 465/500 => Train Loss: 0.4518, Train Acc: 0.9825, Val Loss: 0.4021, Val Acc: 0.9844
# Epoch 466/500 => Train Loss: 0.4545, Train Acc: 0.9866, Val Loss: 0.4089, Val Acc: 0.9767
# Epoch 467/500 => Train Loss: 0.4559, Train Acc: 0.9900, Val Loss: 0.4031, Val Acc: 0.9883
# Epoch 468/500 => Train Loss: 0.4534, Train Acc: 0.9883, Val Loss: 0.3956, Val Acc: 0.9883
# Epoch 469/500 => Train Loss: 0.4432, Train Acc: 0.9866, Val Loss: 0.4091, Val Acc: 0.9844
# Epoch 470/500 => Train Loss: 0.4532, Train Acc: 0.9883, Val Loss: 0.4203, Val Acc: 0.9728
# Epoch 471/500 => Train Loss: 0.4578, Train Acc: 0.9833, Val Loss: 0.3957, Val Acc: 0.9883
# Epoch 472/500 => Train Loss: 0.4531, Train Acc: 0.9850, Val Loss: 0.4149, Val Acc: 0.9728
# Epoch 473/500 => Train Loss: 0.4474, Train Acc: 0.9908, Val Loss: 0.4057, Val Acc: 0.9805
# Epoch 474/500 => Train Loss: 0.4674, Train Acc: 0.9774, Val Loss: 0.4170, Val Acc: 0.9728
# Epoch 475/500 => Train Loss: 0.4498, Train Acc: 0.9858, Val Loss: 0.4223, Val Acc: 0.9728
# Epoch 476/500 => Train Loss: 0.4468, Train Acc: 0.9825, Val Loss: 0.4259, Val Acc: 0.9767
# Epoch 477/500 => Train Loss: 0.4568, Train Acc: 0.9833, Val Loss: 0.4131, Val Acc: 0.9805
# Epoch 478/500 => Train Loss: 0.4587, Train Acc: 0.9833, Val Loss: 0.4011, Val Acc: 0.9767
# Epoch 479/500 => Train Loss: 0.4529, Train Acc: 0.9825, Val Loss: 0.4166, Val Acc: 0.9689
# Epoch 480/500 => Train Loss: 0.4716, Train Acc: 0.9774, Val Loss: 0.4153, Val Acc: 0.9728
# Epoch 481/500 => Train Loss: 0.4554, Train Acc: 0.9850, Val Loss: 0.4060, Val Acc: 0.9844
# Epoch 482/500 => Train Loss: 0.4530, Train Acc: 0.9841, Val Loss: 0.4056, Val Acc: 0.9844
# Epoch 483/500 => Train Loss: 0.4464, Train Acc: 0.9900, Val Loss: 0.4005, Val Acc: 0.9844
# Epoch 484/500 => Train Loss: 0.4472, Train Acc: 0.9883, Val Loss: 0.4253, Val Acc: 0.9767
# Epoch 485/500 => Train Loss: 0.4544, Train Acc: 0.9866, Val Loss: 0.4167, Val Acc: 0.9650
# Epoch 486/500 => Train Loss: 0.4523, Train Acc: 0.9866, Val Loss: 0.4071, Val Acc: 0.9883
# Epoch 487/500 => Train Loss: 0.4538, Train Acc: 0.9875, Val Loss: 0.4188, Val Acc: 0.9728
# Epoch 488/500 => Train Loss: 0.4421, Train Acc: 0.9891, Val Loss: 0.4135, Val Acc: 0.9689
# Epoch 489/500 => Train Loss: 0.4452, Train Acc: 0.9916, Val Loss: 0.4181, Val Acc: 0.9767
# Epoch 490/500 => Train Loss: 0.4518, Train Acc: 0.9816, Val Loss: 0.4001, Val Acc: 0.9844
# Epoch 491/500 => Train Loss: 0.4527, Train Acc: 0.9850, Val Loss: 0.4126, Val Acc: 0.9805
# Epoch 492/500 => Train Loss: 0.4487, Train Acc: 0.9883, Val Loss: 0.4042, Val Acc: 0.9844
# Epoch 493/500 => Train Loss: 0.4516, Train Acc: 0.9883, Val Loss: 0.4131, Val Acc: 0.9844
# Epoch 494/500 => Train Loss: 0.4537, Train Acc: 0.9858, Val Loss: 0.4016, Val Acc: 0.9844
# Epoch 495/500 => Train Loss: 0.4630, Train Acc: 0.9808, Val Loss: 0.4061, Val Acc: 0.9844
# Epoch 496/500 => Train Loss: 0.4530, Train Acc: 0.9866, Val Loss: 0.4142, Val Acc: 0.9767
# Epoch 497/500 => Train Loss: 0.4529, Train Acc: 0.9875, Val Loss: 0.4015, Val Acc: 0.9844
# Epoch 498/500 => Train Loss: 0.4524, Train Acc: 0.9875, Val Loss: 0.4015, Val Acc: 0.9883
# Epoch 499/500 => Train Loss: 0.4469, Train Acc: 0.9866, Val Loss: 0.4125, Val Acc: 0.9767
# Epoch 500/500 => Train Loss: 0.4496, Train Acc: 0.9900, Val Loss: 0.4030, Val Acc: 0.9844
# Training Time: 3019.95 seconds ---> 50.33 minutes

# %%
history = pd.read_excel('/kaggle/working/custom_custom_training_data.xlsx')

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history['Epoch'], history['Train Loss'], label='Train Loss')
plt.plot(history['Validation Loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')
plt.ylim(0,2)

plt.subplot(1, 2, 2)
plt.plot(history['Epoch'], history['Train Accuracy'], label='Train Accuracy')
plt.plot(history['Validation Accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')
plt.ylim(0,1.1)

plt.show()

# %% [markdown]
# ### Evaluation

# %%
def evaluate_model(model, criterion, dataloader):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
        
            _, predicted = torch.max(outputs, 1)
            running_loss += loss.item() * inputs.size(0)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    loss = running_loss / total
    accuracy = correct / total

    return loss, accuracy

# %%
best_checkpoint_path = f"{save_path_checkpoints}/model.pt"
checkpoint = torch.load(best_checkpoint_path)
best_epoch = checkpoint["epoch"]
model.load_state_dict(checkpoint["model_weight"])
optimizer.load_state_dict(checkpoint["optimizer_state"])

best_val_loss, best_val_accuracy = evaluate_model(model, criterion, dataloader_valid_dataset)
print(f"Best model (from epoch {best_epoch}) - Validation Loss: {best_val_loss:.3f}, Validation Accuracy: {best_val_accuracy:.3f}")
# Out:
# Best model (from epoch 357) - Validation Loss: 0.395, Validation Accuracy: 0.988

# %%
# Grad-CAM
import torch
import numpy as np
import matplotlib.pyplot as plt
import PIL.Image
from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.image import show_cam_on_image, preprocess_image

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
save_path_checkpoints = "/kaggle/working"

# --- Model loading ---
model = CustomCNN(num_classes=num_classes)  # recreate model
best_checkpoint_path = f"{save_path_checkpoints}/model.pt"
checkpoint = torch.load(best_checkpoint_path, map_location=device)
best_epoch = checkpoint["epoch"]
model.load_state_dict(checkpoint["model_weight"])
model = model.to(device)

best_val_loss, best_val_accuracy = evaluate_model(model, criterion, dataloader_valid_dataset)
print(f"Best model (from epoch {best_epoch}) - Validation Loss: {best_val_loss:.3f}, Validation Accuracy: {best_val_accuracy:.3f}")

# --- Grad-CAM ---
target_layer = model.features[6]  # last conv layer in CustomCNN
cam = GradCAM(model=model, target_layers=[target_layer])

class_names = [str(i) for i in range(num_classes)]

def visualize_gradcam(image_path, model, cam, class_names):
    rgb_img = np.array(PIL.Image.open(image_path).resize((128, 128))) / 255.0
    
    input_tensor = preprocess_image(
        rgb_img,
        mean=[0.5, 0.5, 0.5],
        std=[0.5, 0.5, 0.5]
    ).to(device).float()   # ✅ force float32
    
    grayscale_cam = cam(input_tensor=input_tensor)[0, :]
    visualization = show_cam_on_image(rgb_img, grayscale_cam, use_rgb=True)
    plt.imshow(visualization)
    plt.axis('off')
    plt.show()


# Example usage with a test image
example_img_path = test_df.iloc[0]['file_path']
visualize_gradcam(example_img_path, model, cam, class_names)
# Out:
# Best model (from epoch 357) - Validation Loss: 0.395, Validation Accuracy: 0.988

# %%
start_time = time.time()

test_loss, test_accuracy = evaluate_model(model, criterion, dataloader_test_dataset)
print(f"Test Accuracy: {test_accuracy:.3f}")

end_time = time.time()
test_time = end_time - start_time
print(f"Test Time: {test_time:.2f} seconds ---> {test_time/60:.2f} minutes")
# Out:
# Test Accuracy: 0.981
# Test Time: 1.98 seconds ---> 0.03 minutes

# %%
def class_accuracy(model, dataloader, num_classes):
    class_correct = [0.0] * num_classes
    class_total = [0.0] * num_classes

    model.eval()
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            correct = (predicted == labels)
            for i in range(len(labels)):
                label = labels[i]
                class_correct[label] += correct[i].item()
                class_total[label] += 1

    class_accuracy = [class_correct[i] / class_total[i] if class_total[i] > 0 else 0 for i in range(num_classes)]

    return class_accuracy

y_true = []
y_pred = []

model.eval()
with torch.no_grad():
    for inputs, labels in dataloader_test_dataset:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())

y_true = np.array(y_true)
y_pred = np.array(y_pred)

class_names = [str(i) for i in range(num_classes)]

print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))

class_acc = class_accuracy(model, dataloader_test_dataset, num_classes)
for i in range(num_classes):
    print(f"Class {i} Accuracy: {class_acc[i]:.3f}")

# Confusion Matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        63
#            1       0.94      1.00      0.97        62
#            2       1.00      0.92      0.96        64
#            3       1.00      1.00      1.00        68
#
#     accuracy                           0.98       257
#    macro avg       0.98      0.98      0.98       257
# weighted avg       0.98      0.98      0.98       257
#
# Class 0 Accuracy: 1.000
# Class 1 Accuracy: 1.000
# Class 2 Accuracy: 0.922
# Class 3 Accuracy: 1.000
